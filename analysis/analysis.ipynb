# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
kabura_fc = pd.read_csv('../data/flight_computer/kabura.csv',
              names=["time", "a", "b", "c", "d", "e", "f", "altitude","filtered_altitude","g","h","i","j","k"])

tembo = pd.read_csv('../data/base_station/log_2216436.csv',
                    names = ["time","a","b","c",'d','e','f','altitude','filtered_altitude','h','i','j'])
kabura = pd.read_csv('../data/base_station/log_3132638.csv')
simba = pd.read_csv('../data/base_station/log_4886530.csv')

# %%
kabura_fc
# Out:
#          time     a     b      c     d     e     f  altitude  \
# 0       64770  1.18  1.05  13.71 -0.85  0.06  0.65   1309.89
# 1       64890 -1.13 -4.83  13.24 -1.22  0.10  0.06   1310.45
# 2       65017 -2.59 -3.12  12.86 -0.52 -0.24 -0.25   1310.17
# 3       65152 -1.51 -0.38  12.48 -0.55 -0.31  1.45   1311.10
# 4       65285 -1.68 -0.96  11.98 -0.78 -1.38  2.82   1310.26
# ...       ...   ...   ...    ...   ...   ...   ...       ...
# 6956  1328564  0.80 -9.11  -0.59 -0.09  0.02 -0.06    941.88
# 6957  1331426  0.71 -9.07  -0.41 -0.09  0.01 -0.06    942.06
# 6958  1334702  0.55 -9.06   0.01 -0.09  0.01 -0.06    941.97
# 6959  1338696  0.26 -9.79   0.80  0.87  0.03  0.36    941.43
# 6960  1340872 -0.56 -9.74   2.63 -0.13  0.02 -0.07    941.25
#
#       filtered_altitude     g     h    i    j  k
# 0               1306.04 -1.76 -0.54  0.0  0.0  0
# 1               1306.19 -1.70 -0.52  0.0  0.0  0
# 2               1306.31 -1.64 -0.50  0.0  0.0  0
# ...

# %%
plt.plot(kabura_fc['filtered_altitude'],label="filtered")
plt.plot(kabura_fc['altitude'],label='raw')
plt.ylim([1000,1300])
plt.legend()
plt.title('Flight computer log (Kabura)')
# Out:
# Text(0.5, 1.0, 'Flight computer log (Kabura)')

# %%
plt.plot(tembo['filtered_altitude'],label="filtered")
plt.plot(tembo['altitude'],label='raw')
# plt.ylim([1000,1300])
plt.legend()
plt.title('Base station log (tembo)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/z1/r5wl186d23314ypyzy3t8wj80000gn/T/ipykernel_24037/4166539560.py in <module>
# ----> 1 plt.plot(tembo['filtered_altitude'],label="filtered")
#       2 plt.plot(tembo['altitude'],label='raw')
#       3 # plt.ylim([1000,1300])
#       4 plt.legend()
#       5 plt.title('Base station log (tembo)')
#
# ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
tembo['filtered_altitude']
# .plot()
# tembo
# Out:
# 2024-01-30-08:23:36  4380147  -9.32   -0.02
#                               -9.32   -0.02
#                      4380263  -9.32   -0.02
#                               -9.32   -0.02
#                      4380386  -9.32   -0.02
#                                        ...
# 2024-01-30-08:37:09  5192599  -9.31   -0.01
#                               -9.31   -0.01
#                      5192726  -9.32   -0.01
#                               -9.32   -0.01
#                      5192843  -9.31   -0.01
# Name: filtered_altitude, Length: 12402, dtype: float64

# %%
tembo
# Out:
#                                    time     a     b     c     d       e  \
# 2024-01-30-08:23:36 4380147 -9.32  0.49  1.17 -0.10  0.01 -0.07  897.66
#                             -9.32  0.49  1.17 -0.10  0.01 -0.07  897.66
#                     4380263 -9.32  0.52  1.17 -0.11  0.01 -0.07  897.75
#                             -9.32  0.52  1.17 -0.11  0.01 -0.07  897.75
#                     4380386 -9.32  0.49  1.15 -0.10  0.01 -0.07  897.93
# ...                                 ...   ...   ...   ...   ...     ...
# 2024-01-30-08:37:09 5192599 -9.31  0.52  1.22 -0.11  0.01 -0.07  993.28
#                             -9.31  0.52  1.22 -0.11  0.01 -0.07  993.28
#                     5192726 -9.32  0.53  1.21 -0.11  0.01 -0.07  993.19
#                             -9.32  0.53  1.21 -0.11  0.01 -0.07  993.19
#                     5192843 -9.31  0.51  1.20 -0.11  0.01 -0.07  993.19
#
#                                         f  altitude  filtered_altitude    h  \
# ...
